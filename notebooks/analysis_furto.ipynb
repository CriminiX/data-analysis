# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os 
import glob
import seaborn as sns

# Configurando o max columns para melhor visualização do dataframe
pd.set_option('display.max_columns', 54)

# %%
path = r'G:\\Meu Drive\\7. Share\\analytisis_tcc\\Furtos'
lista_arquivos = glob.glob(f'{path}\\*.xls')

df_furto = pd.DataFrame()

for arquivo in lista_arquivos:
    df_furto = pd.concat([df_furto,pd.read_csv(arquivo, sep='\t', encoding='UTF-16 LE', low_memory=False)])

# %%
df_furto.shape
# Out:
# (338036, 54)

# %%
# 5 primeiras linhas do dataframe
df_furto.head()
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2019  1624939   1624939/2019  01/01/2020 00:14:09  01/01/2020 00:13:36
# 1    2020        1         1/2020  01/01/2020 00:13:03  01/01/2020 00:20:13
# 2    2020        2         2/2020  01/01/2020 00:22:20  01/01/2020 00:23:24
# 3    2020        2         2/2020  01/01/2020 00:51:55  01/01/2020 01:04:20
# 4    2020        1         1/2020  01/01/2020 01:05:18  01/01/2020 01:09:48
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     31/12/2019          19:40          A NOITE      31/12/2019
# 1     31/12/2019          20:00          A NOITE      01/01/2020
# 2     31/12/2019          20:00          A NOITE      01/01/2020
# 3     01/01/2020          00:10     DE MADRUGADA      01/01/2020
# 4     01/01/2020          00:30     DE MADRUGADA      01/01/2020
#
#         DATAELABORACAO    BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# ...

# %%
# Mostrando linhas aleatórias
df_furto.sample(5)
# Out:
#       ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 1866    2021  1215238   1215238/2021  08/07/2021 16:19:29
# 2371    2022     1634      1634/2022  08/03/2022 09:01:21
# 4438    2022     7166      7166/2022  08/12/2022 18:33:47
# 6160    2021   526051    526051/2021  23/03/2021 19:51:29
# 6738    2021     2263      2263/2021  26/07/2021 17:36:57
#
#                BO_EMITIDO DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA  \
# 1866  08/07/2021 16:18:19     08/07/2021          11:45       PELA MANHÃ
# 2371  08/03/2022 12:35:40     08/03/2022          07:44       PELA MANHÃ
# 4438  08/12/2022 18:33:47     08/12/2022          09:00       PELA MANHÃ
# 6160  23/03/2021 19:51:29     23/03/2021          17:15          A TARDE
# 6738  26/07/2021 17:43:24     26/07/2021          17:30          A TARDE
#
#      DATACOMUNICACAO       DATAELABORACAO    BO_AUTORIA FLAGRANTE  \
# 1866      08/07/2021  08/07/2021 16:19:29  Desconhecida       Não
# ...

# %% [markdown]
# ### Visualizando valores faltantes

# %%
df_furto.isnull()
# Out:
#        ANO_BO  NUM_BO  NUMERO_BOLETIM  BO_INICIADO  BO_EMITIDO  \
# 0       False   False           False        False       False
# 1       False   False           False        False       False
# 2       False   False           False        False       False
# 3       False   False           False        False       False
# 4       False   False           False        False       False
# ...       ...     ...             ...          ...         ...
# 15116   False   False           False        False       False
# 15117   False   False           False        False       False
# 15118   False   False           False        False       False
# 15119   False   False           False        False       False
# 15120   False   False           False        False       False
#
#        DATAOCORRENCIA  HORAOCORRENCIA  PERIDOOCORRENCIA  DATACOMUNICACAO  \
# 0               False           False             False            False
# ...

# %%
# Distribuição dos nulls por variável do dataset
sns.heatmap(df_furto.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
percent_missing = df_furto.isnull().sum() * 100 / len(df_furto)
qtde_registros_missing = df_furto.isnull().sum()
missing_values =  pd.DataFrame({'percent_missing': percent_missing})
missing_values.sort_values(by='percent_missing').plot(kind='barh', figsize=(10, 12))
# Out:
# <Axes: >

# %%
# Selecionando colunas úteis
df_furto_uteis = df_furto[[
    'ANO_BO', 
    'NUMERO_BOLETIM', 
    'BO_EMITIDO', 
    'HORAOCORRENCIA',
    'DATACOMUNICACAO', 
    'BO_AUTORIA',
    'NUMERO', 
    'CIDADE', 
    'LATITUDE',
    'LONGITUDE', 
    'DESCRICAOLOCAL', 
    'SOLUCAO', 
    'DELEGACIA_CIRCUNSCRICAO',
    'RUBRICA', 
    'STATUS', 
    'PLACA_VEICULO', 
    'CIDADE_VEICULO', 
    'DESCR_MARCA_VEICULO', 
    'ANO_MODELO', 
    'UF', 
    'BAIRRO', 
    'DESCR_TIPO_VEICULO',
    'DESCR_COR_VEICULO'
]]

# %%
df_furto_uteis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338036 entries, 0 to 15120
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ANO_BO                   338036 non-null  int64
#  1   NUMERO_BOLETIM           338036 non-null  object
#  2   BO_EMITIDO               338036 non-null  object
#  3   HORAOCORRENCIA           288610 non-null  object
#  4   DATACOMUNICACAO          338036 non-null  object
#  5   BO_AUTORIA               338036 non-null  object
#  6   NUMERO                   337968 non-null  float64
#  7   CIDADE                   337968 non-null  object
#  8   LATITUDE                 290789 non-null  object
#  9   LONGITUDE                290789 non-null  object
#  10  DESCRICAOLOCAL           338036 non-null  object
#  11  SOLUCAO                  338036 non-null  object
#  12  DELEGACIA_CIRCUNSCRICAO  338036 non-null  object
# ...

# %%
df_furto_uteis['ANO_MODELO'] = df_furto_uteis['ANO_MODELO'].astype(str)
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_24376\196873555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_furto_uteis['ANO_MODELO'] = df_furto_uteis['ANO_MODELO'].astype(str)

# %%
df_furto_uteis['DELEGACIA_CIRCUNSCRICAO'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df_furto_uteis['STATUS'].value_counts()
# Out:
# Consumado    337618
# Tentado         418
# Name: STATUS, dtype: int64

# %%
df_furto_uteis['DATACOMUNICACAO'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df_furto_uteis['SOLUCAO'].value_counts()
# Out:
# BO PARA INVESTIGAÇÃO              164262
# ENCAMINHAMENTO DP ÁREA DO FATO     62005
# APRECIAÇÃO DO DELEGADO TITULAR     56550
# BO PARA REGISTRO                   23579
# BO PARA FLAGRANTE                  20402
# BO PARA ADENDO                      7156
# ENCAM FEBEM/V.INFAN.JUVENTUDE       2519
# BO PARA INQUÉRITO                    908
# AGUARDANDO LAUDOS                    238
# AG. REPRESENTAÇÃO/REQUERIMENTO       224
# ENCAMINHAMENTO JECRIM                165
# OFÍCIO                                28
# Name: SOLUCAO, dtype: int64

# %%
df_furto_uteis['CIDADE_VEICULO'].describe()
# Out:
# count      288343
# unique       2271
# top       S.PAULO
# freq        53879
# Name: CIDADE_VEICULO, dtype: object

# %%
# Podemos perceber que precisamos fazer a tratativa do campo CIDADE_VEICULO pois as nomes estão escritos de formas diferentes
df_furto_uteis['CIDADE_VEICULO'].value_counts(sort = True).head(10).plot(kind='barh', figsize=(10,5))
# Out:
# <Axes: >

# %%
df_furto_uteis['UF'].describe()
# Out:
# count     337968
# unique         1
# top           SP
# freq      337968
# Name: UF, dtype: object

# %%
df_furto_uteis['BAIRRO'].value_counts(sort = True).head(10).plot(kind='barh', figsize=(10,5))
# Out:
# <Axes: >

# %%
df_furto_uteis['BAIRRO'].value_counts(sort = True).head(10).reset_index().to_csv('furto_bairos.csv', sep=';', index=False)

# %%
df_furto_uteis['UF'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
df_furto_uteis['DESCR_MARCA_VEICULO'].value_counts()
# Out:
# HONDA/CG 160 FAN            7241
# GM/CORSA WIND               4991
# HONDA/CG 160 TITAN          4282
# FIAT/MOBI LIKE              3523
# HYUNDAI/HB20 1.0M COMFOR    3275
#                             ...
# FIAT/DUCATO M RONTAN AMB       1
# I/HARLEY DAVIDSON FLSTF        1
# IMP/HONDA CIVIC 3D SI          1
# I/LR DISCOVERY 4 2.7 HSE       1
# HONDA/HR-V LX MT               1
# Name: DESCR_MARCA_VEICULO, Length: 6598, dtype: int64

# %%
df_furto_uteis['DESCR_MARCA_VEICULO'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df_furto_uteis['DESCR_TIPO_VEICULO'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df_furto_uteis['LONGITUDE'] = df_furto_uteis['LONGITUDE'].str.replace(',', '.').astype(np.float64)
df_furto_uteis['LATITUDE'] = df_furto_uteis['LATITUDE'].str.replace(',', '.').astype(np.float64)
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_24376\4011606071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_furto_uteis['LONGITUDE'] = df_furto_uteis['LONGITUDE'].str.replace(',', '.').astype(np.float64)
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_24376\4011606071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_furto_uteis['LATITUDE'] = df_furto_uteis['LATITUDE'].str.replace(',', '.').astype(np.float64)

# %%
df_furto_uteis['LATITUDE'].value_counts()
# Out:
# -23.283332    1715
# -22.839824    1273
# -23.282144     454
# -23.282513     351
# -22.387438     275
#               ...
# -21.778285       1
# -23.544737       1
# -23.955772       1
# -22.886307       1
# -23.551306       1
# Name: LATITUDE, Length: 168936, dtype: int64

# %%
df_furto_uteis['LONGITUDE'].value_counts()
# Out:
# -47.668921    1715
# -47.035171    1273
# -47.668167     454
# -47.668448     351
# -47.544532     275
#               ...
# -46.559258       1
# -46.567419       1
# -46.558028       1
# -46.692000       1
# -46.500016       1
# Name: LONGITUDE, Length: 168767, dtype: int64

# %%
# Plotando LAT e LONG
plt.scatter(x=df_furto_uteis['LONGITUDE'], y=df_furto_uteis['LATITUDE'])
plt.show()

# %%
# df_furto_uteis['CIDADE_VEICULO'].plot()
# result = df_furto_uteis.isna().sum() / len(df_furto_uteis) * 100
# result.sort_values().plot(kind='barh')

# %%
# x = df_furto_uteis['DESCR_MARCA_VEICULO'].value_counts()
# y = df_furto_uteis['SOLUCAO'].value_counts()

# plt.scatter(x, y)

# %%
# Quantidade de BOs por ANO
df_furto_uteis['ANO_BO'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Kmeans

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
df_veic = df_furto_uteis[[
    'DESCR_MARCA_VEICULO',   
    'DESCR_COR_VEICULO',
    'DESCR_TIPO_VEICULO',
    'BAIRRO',
    'LONGITUDE',
    'LATITUDE'
]].query("""LONGITUDE.notnull() and DESCR_MARCA_VEICULO.notnull() and DESCR_TIPO_VEICULO.notnull() and DESCR_COR_VEICULO.notnull()""")

# %%
df_veic.isna().sum()
# Out:
# DESCR_MARCA_VEICULO       0
# DESCR_COR_VEICULO         0
# DESCR_TIPO_VEICULO        0
# BAIRRO                 1512
# LONGITUDE                 0
# LATITUDE                  0
# dtype: int64

# %%
df_veic[['LONGITUDE', 'LATITUDE']] = df_veic[['LONGITUDE', 'LATITUDE']].replace(r',', '.', regex=True)\
  .astype({'LONGITUDE': 'double', 'LATITUDE': 'double'})

# %%
categorical = make_pipeline(
    SimpleImputer(strategy='most_frequent'),
    OneHotEncoder(drop='first')
)

numerical = make_pipeline(
    StandardScaler()
)

# %%
categorical_cols = ['DESCR_MARCA_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_TIPO_VEICULO', 'BAIRRO']
numerical_cols   = ['LATITUDE', 'LONGITUDE']

tranformer = ColumnTransformer(transformers=[
    ('categorical', categorical, categorical_cols),
    ('numerical', numerical, numerical_cols)
])

# %%
X = tranformer.fit_transform(df_veic)

# %%
# Pegando apenas longitude e latitude
X = df_veic.iloc[:, [4, 5]]

n_clusters = 10
kmeans = KMeans(
    n_clusters=n_clusters,
    random_state=0
)

kmeans.fit(X)
labels = kmeans.labels_
X['cluster'] = labels
# Out:
# C:\Users\gabriel\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_24376\565008412.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = labels

# %%
_clusters = X.groupby('cluster').count()
# _clusters
_clusters
# Out:
#          LONGITUDE  LATITUDE
# cluster
# 0            76023     76023
# 1             5297      5297
# 2            28629     28629
# 3             9555      9555
# 4             2947      2947
# 5             4447      4447
# 6             7575      7575
# 7             9095      9095
# 8             4174      4174
# 9            98477     98477

# %%
X = X.reset_index()

ptsymb = np.array(['b.','r.','m.','g.','c.','k.','b*','r*','m*','r^']);
plt.figure(figsize=(10,10))
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
for i in range(n_clusters):
    cluster=np.where(labels==i)[0]
    plt.plot(X['LONGITUDE'][cluster].values, X['LATITUDE'][cluster].values, ptsymb[i])
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
silhouette_score(X, )

# %%
X = X.reset_index(drop=True)

ptsymb = np.array(['b.','r.','m.','g.','c.','k.','b*','r*','m*','r^']);
plt.figure(figsize=(10,10))
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
for i in range(n_clusters):
    cluster=np.where(labels==i)[0]
    plt.plot(X['LONGITUDE'][cluster].values, X['LATITUDE'][cluster].values)
plt.show()

# %%
X
